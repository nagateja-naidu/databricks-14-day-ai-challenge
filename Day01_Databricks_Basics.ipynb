# %%
spark

# %%
data=[("Naga",92),("Babu",90),("Tharun",91)]
df=spark.createDataFrame(data,["name","age"])
df.show()
# Out:
# +------+---+
# |  name|age|
# +------+---+
# |  Naga| 92|
# |  Babu| 90|
# |Tharun| 91|
# +------+---+

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)

# %%
df.filter(df.age>28).show()
# Out:
# +------+---+
# |  name|age|
# +------+---+
# |  Naga| 92|
# |  Babu| 90|
# |Tharun| 91|
# +------+---+

# %%
df.select("name").show()
# Out:
# +------+
# |  name|
# +------+
# |  Naga|
# |  Babu|
# |Tharun|
# +------+

# %%
df.count()
# Out:
# 3
